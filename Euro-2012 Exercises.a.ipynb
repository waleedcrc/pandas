# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
#Euro_2012_stats_TEAM = pd.read_csv(r"C:\Users\Waleed\Desktop\zain piaic files\piaic-datascience-teaching-master\piaic-datascience-teaching-master\PIAIC-Sir-Anees-Quarter-2\Assignment-2\Euro_2012_stats_TEAM.csv")
#Euro_2012_stats_TEAM.head()
#print(Euro_2012_stats_TEAM)

# %% [markdown]
# ### Step 2. Import the dataset Euro_2012_stats_TEAM

# %% [markdown]
# ### Step 3. Assign it to a variable called euro12.

# %%
Euro_2012_stats_TEAM = pd.read_csv(r"C:\Users\Waleed\Desktop\zain piaic files\piaic-datascience-teaching-master\piaic-datascience-teaching-master\PIAIC-Sir-Anees-Quarter-2\Assignment-2\Euro_2012_stats_TEAM.csv")
#Euro_2012_stats_TEAM.head()#its mean only starting 5 opening heading
#print(Euro_2012_stats_TEAM)
display(Euro_2012_stats_TEAM)
# Out:
#                                                  Team  Goals  Shots on target  \
# 0                                             Croatia    4.0             13.0
# 1                                      Czech Republic    4.0             13.0
# 2                                             Denmark    4.0             10.0
# 3                                             England    5.0             11.0
# 4                                              France    3.0             22.0
# 5                                             Germany   10.0             32.0
# 6                                              Greece    5.0              8.0
# 7                                               Italy    6.0             34.0
# 8                                         Netherlands    2.0             12.0
# 9                                              Poland    2.0             15.0
# 10                                           Portugal    6.0             22.0
# ...

# %% [markdown]
# ### Step 4. Select only the Goal column.

# %%
Euro_2012_stats_TEAM.Goals
#Euro_2012_stats_TEAM.Team
#x =Euro_2012_stats_TEAM.Goals
#display(x)
# Out:
# 0      4.0
# 1      4.0
# 2      4.0
# 3      5.0
# 4      3.0
# 5     10.0
# 6      5.0
# 7      6.0
# 8      2.0
# 9      2.0
# 10     6.0
# 11     1.0
# 12     5.0
# 13    12.0
# 14     5.0
# 15     2.0
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# Name: Goals, dtype: float64

# %% [markdown]
# ### Step 5. How many team participated in the Euro2012?

# %%
Euro_2012_stats_TEAM.shape[0]
#Euro_2012_stats_TEAM.shape
# Out:
# 20

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
Euro_2012_stats_TEAM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 35 columns):
# Team                          17 non-null object
# Goals                         16 non-null float64
# Shots on target               16 non-null float64
# Shots off target              16 non-null float64
# Shooting Accuracy             16 non-null object
# % Goals-to-shots              16 non-null object
# Total shots (inc. Blocked)    16 non-null float64
# Hit Woodwork                  16 non-null float64
# Penalty goals                 16 non-null float64
# Penalties not scored          16 non-null float64
# Headed goals                  16 non-null float64
# Passes                        16 non-null float64
# Passes completed              16 non-null float64
# Passing Accuracy              16 non-null object
# Touches                       16 non-null float64
# Crosses                       16 non-null float64
# Dribbles                      16 non-null float64
# ...

# %% [markdown]
# ### Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
discipline = Euro_2012_stats_TEAM [["Team","Yellow Cards","Red Cards"]]
discipline
# Out:
#                                                  Team  Yellow Cards  Red Cards
# 0                                             Croatia           9.0        0.0
# 1                                      Czech Republic           7.0        0.0
# 2                                             Denmark           4.0        0.0
# 3                                             England           5.0        0.0
# 4                                              France           6.0        0.0
# 5                                             Germany           4.0        0.0
# 6                                              Greece           9.0        1.0
# 7                                               Italy          16.0        0.0
# 8                                         Netherlands           5.0        0.0
# 9                                              Poland           7.0        1.0
# 10                                           Portugal          12.0        0.0
# ...

# %% [markdown]
# ### Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
#discipline.sort_values("Red cards")
discipline.sort_values(['Red cards','Yellow Cards']),axis=0,ascending = False
# Out:
#   File "<ipython-input-150-49c19e2d11a0>", line 2
#     discipline.sort_values(['Red cards','Yellow Cards']),axis=0,ascending = False
#                                                                                  ^
# SyntaxError: can't assign to function call

# %% [markdown]
# ### Step 9. Calculate the mean Yellow Cards given per Team

# %%
y=round(discipline["Yellow Cards"]).mean()
#x =round(discipline["Red Cards"]).mean()
#print(x)
print(y)
# Out:
# 7.4375

# %% [markdown]
# ### Step 10. Filter teams that scored more than 6 goals

# %%
Euro_2012_stats_TEAM[Euro_2012_stats_TEAM.Goals > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany   10.0             32.0              32.0            47.80%
# 13    Spain   12.0             42.0              33.0            55.90%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.60%                        80.0           2.0            1.0
# 13           16.00%                       100.0           0.0            1.0
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                    0.0  ...        10.0                62.60%       63.0
# 13                   0.0  ...        15.0                93.80%      102.0
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5            49.0      12.0           4.0        0.0     15.0      15.0
# 13           83.0      19.0          11.0        0.0     17.0      17.0
#
#     Players Used
# 5           17.0
# 13          18.0
#
# ...

# %% [markdown]
# ### Step 11. Select the teams that start with G

# %%
Euro_2012_stats_TEAM[5:7]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany   10.0             32.0              32.0            47.80%
# 6   Greece    5.0              8.0              18.0            30.70%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5           15.60%                        80.0           2.0            1.0
# 6           19.20%                        32.0           1.0            1.0
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                   0.0  ...        10.0                62.60%       63.0
# 6                   1.0  ...        13.0                65.10%       67.0
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5           49.0      12.0           4.0        0.0     15.0      15.0
# 6           48.0      12.0           9.0        1.0     12.0      12.0
#
#    Players Used
# 5          17.0
# 6          20.0
#
# [2 rows x 35 columns]

# %% [markdown]
# ### Step 12. Select the first 7 columns

# %%
Euro_2012_stats_TEAM.iloc[:, list(range(7)) + [-1]]
#Euro_2012_stats_TEAM.iloc[:,7]
#Euro_2012_stats_TEAM.columns[(7)]
# Out:
#                                                  Team  Goals  Shots on target  \
# 0                                             Croatia    4.0             13.0
# 1                                      Czech Republic    4.0             13.0
# 2                                             Denmark    4.0             10.0
# 3                                             England    5.0             11.0
# 4                                              France    3.0             22.0
# 5                                             Germany   10.0             32.0
# 6                                              Greece    5.0              8.0
# 7                                               Italy    6.0             34.0
# 8                                         Netherlands    2.0             12.0
# 9                                              Poland    2.0             15.0
# 10                                           Portugal    6.0             22.0
# ...

# %% [markdown]
# ### Step 13. Select all columns except the last 3.

# %%
Euro_2012_stats_TEAM.iloc[:,:-3]
#Euro_2012_stats_TEAM.iloc[:-3]
#Euro_2012_stats_TEAM.columns
# Out:
#                                                  Team  Goals  Shots on target  \
# 0                                             Croatia    4.0             13.0
# 1                                      Czech Republic    4.0             13.0
# 2                                             Denmark    4.0             10.0
# 3                                             England    5.0             11.0
# 4                                              France    3.0             22.0
# 5                                             Germany   10.0             32.0
# 6                                              Greece    5.0              8.0
# 7                                               Italy    6.0             34.0
# 8                                         Netherlands    2.0             12.0
# 9                                              Poland    2.0             15.0
# 10                                           Portugal    6.0             22.0
# ...

# %% [markdown]
# ### Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
Euro_2012_stats_TEAM.loc[[3,7,12],["Team","Shooting Accuracy"]]
# Out:
#        Team Shooting Accuracy
# 3   England            50.00%
# 7     Italy            43.00%
# 12   Russia            22.50%

# %% [markdown]
# # #Step 15. Use apply method on Goal Column to make a new column called Performance, using following conditions
#
# 1. If Goals are less than or equal to 2, peformance is **Below Avg**
# 2. If Goals are more than 2 and less than or equal to 5, peformance is **Average**
# 3. If Goals are more than 5 and less than or equal to 10, peformance is **Above Average**
# 4. If Goals are more than 10 then peformance is **Excellent**
